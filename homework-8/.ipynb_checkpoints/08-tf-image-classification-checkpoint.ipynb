# %% [markdown]
# # Homework 8 - Image Classification with Tensorflow and Keras

# %% [markdown]
# ## Dataset

# %% [markdown]
# In this homework, we'll build a model for predicting if we have an image of a bee or a wasp.
# For this, we will use the "Bee or Wasp?" dataset that was obtained from [Kaggle](https://www.kaggle.com/datasets/jerzydziewierz/bee-vs-wasp) and slightly rebuilt.
#
# You can download the dataset for this homework from [here](https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip):
#
# ```bash
# wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip
# unzip data.zip
# ```

# %%
# Uncomment to run
#!wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip
#!unzip data.zip

# %% [markdown]
# In the lectures we saw how to use a pre-trained neural network. In the homework, we'll train a much smaller model from scratch.
#
# > **Note:** you will need an environment with a GPU for this homework. We recommend to use [Saturn Cloud](https://bit.ly/saturn-mlzoomcamp).
# > You can also use a computer without a GPU (e.g. your laptop), but it will be slower.

# %% [markdown]
# ### Data Preparation
#
# The dataset contains around 2500 images of bees and around 2100 images of wasps.
#
# The dataset contains separate folders for training and test sets.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %matplotlib inline

# %%
path = "./data/train/bee"
name = "21004953130_03d69a5dee_w.jpg"
fullname = f'{path}/{name}'
load_img(fullname)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x225>

# %% [markdown]
# ### Model
#
# For this homework we will use Convolutional Neural Network (CNN). Like in the lectures, we'll use Keras.
#
# You need to develop the model with following structure:
#
# * The shape for input should be `(150, 150, 3)`
# * Next, create a convolutional layer ([`Conv2D`](https://keras.io/api/layers/convolution_layers/convolution2d/)):
#     * Use 32 filters
#     * Kernel size should be `(3, 3)` (that's the size of the filter)
#     * Use `'relu'` as activation
# * Reduce the size of the feature map with max pooling ([`MaxPooling2D`](https://keras.io/api/layers/pooling_layers/max_pooling2d/))
#     * Set the pooling size to `(2, 2)`
# * Turn the multi-dimensional result into vectors using a [`Flatten`](https://keras.io/api/layers/reshaping_layers/flatten/) layer
# * Next, add a `Dense` layer with 64 neurons and `'relu'` activation
# * Finally, create the `Dense` layer with 1 neuron - this will be the output
#     * The output layer should have an activation - use the appropriate activation for the binary classification case
#
# As optimizer use [`SGD`](https://keras.io/api/optimizers/sgd/) with the following parameters:
#
# * `SGD(lr=0.002, momentum=0.8)`
#
# For clarification about kernel size and max pooling, check [Office Hours](https://www.youtube.com/watch?v=1WRgdBTUaAc).

# %%
inputs = keras.Input(shape=(150, 150, 3))
convol = keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu')(inputs)
pooling = keras.layers.MaxPool2D(pool_size=(2,2))(convol)
vectors = keras.layers.Flatten()(pooling)
hidden1 = keras.layers.Dense(64, activation='relu')(vectors)
outputs = keras.layers.Dense(1, activation='sigmoid')(hidden1)

model = keras.Model(inputs, outputs)

# %% [markdown]
# ### Question 1
#
# Since we have a binary classification problem, what is the best loss function for us?
#
# * `mean squared error`
# * `binary crossentropy`  <--
# * `categorical crossentropy`
# * `cosine similarity`
#
# > **Note:** since we specify an activation for the output layer, we don't need to set `from_logits=True`

# %%
optimizer = keras.optimizers.SGD(learning_rate=0.002, momentum=0.8)
loss = keras.losses.BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_4 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  flatten_4 (Flatten)         (None, 175232)            0
#
#  dense_8 (Dense)             (None, 64)                11214912
#
#  dense_9 (Dense)             (None, 1)                 65
#
# ...
# Total params: 11,215,873
# Trainable params: 11,215,873
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Question 2
#
# What's the number of parameters in the convolutional layer of our model? You can use the `summary` method for that.
#
# * 1
# * 65
# * 896  <--
# * 11214912

# %% [markdown]
# ### Generators and Training
#
# For the next two questions, use the following data generator for both train and test sets:
#
# ```python
# ImageDataGenerator(rescale=1./255)
# ```
#
# * We don't need to do any additional pre-processing for the images.
# * When reading the data from train/test directories, check the `class_mode` parameter. Which value should it be for a binary classification problem?
# * Use `batch_size=20`
# * Use `shuffle=True` for both training and test sets.
#
# For training use `.fit()` with the following params:
#
# ```python
# model.fit(
#     train_generator,
#     epochs=10,
#     validation_data=test_generator
# )
# ```

# %%
data_generator = ImageDataGenerator(rescale=1./255)

train_ds = data_generator.flow_from_directory(
    './data/train',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',
    shuffle=True
)
# Out:
# Found 3678 images belonging to 2 classes.

# %%
train_ds.class_indices
# Out:
# {'bee': 0, 'wasp': 1}

# %%
test_ds = data_generator.flow_from_directory(
    './data/test',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 918 images belonging to 2 classes.

# %%
history = model.fit(
    train_ds,
    epochs=10,
    validation_data=test_ds
)
# Out:
# Epoch 1/10
# 184/184 [==============================] - 8s 43ms/step - loss: 0.6848 - accuracy: 0.5424 - val_loss: 0.6644 - val_accuracy: 0.5425
# Epoch 2/10
# 184/184 [==============================] - 8s 43ms/step - loss: 0.6633 - accuracy: 0.5723 - val_loss: 0.6320 - val_accuracy: 0.6253
# Epoch 3/10
# 184/184 [==============================] - 8s 43ms/step - loss: 0.6498 - accuracy: 0.6011 - val_loss: 0.6252 - val_accuracy: 0.6068
# Epoch 4/10
# 184/184 [==============================] - 8s 43ms/step - loss: 0.6299 - accuracy: 0.6330 - val_loss: 0.6075 - val_accuracy: 0.6231
# Epoch 5/10
# 184/184 [==============================] - 8s 45ms/step - loss: 0.5942 - accuracy: 0.6789 - val_loss: 0.5836 - val_accuracy: 0.6797
# Epoch 6/10
# 184/184 [==============================] - 8s 44ms/step - loss: 0.5507 - accuracy: 0.7200 - val_loss: 0.5405 - val_accuracy: 0.7397
# Epoch 7/10
# ...

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ### Question 3
#
# What is the median of training accuracy for all the epochs for this model?
#
# * 0.20
# * 0.40
# * 0.60
# * 0.80  <--
#
# ### Question 4
#
# What is the standard deviation of training loss for all the epochs for this model?
#
# * 0.031
# * 0.061
# * 0.091  <--
# * 0.131

# %%
print(np.median(history.history['accuracy']))
# Out:
# 0.6994290351867676

# %%
print(np.std(history.history['loss']))
# Out:
# 0.08606144292240785

# %%
def make_history_df(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    round_epochs = list(range(1, len(history.history['accuracy'])+1))
    cumulative_epochs = round_epochs.copy()
    
    history_df = pd.DataFrame({'round_epoch': round_epochs,'cumulative_epoch': cumulative_epochs, 'accuracy': acc, 'loss': loss, 'val_accuracy': val_acc, 'val_loss': val_loss}, 
                             columns=['round_epoch', 'cumulative_epoch', 'loss', 'accuracy', 'val_loss', 'val_accuracy'])
    
    return history_df

# %%
history_record = make_history_df(history)
history_record.tail(10)
# Out:
#    round_epoch  cumulative_epoch      loss  accuracy  val_loss  val_accuracy
# 0            1                 1  0.684825  0.542414  0.664417      0.542484
# 1            2                 2  0.663260  0.572322  0.632038      0.625272
# 2            3                 3  0.649838  0.601142  0.625231      0.606754
# 3            4                 4  0.629926  0.632953  0.607546      0.623094
# 4            5                 5  0.594216  0.678902  0.583573      0.679739
# 5            6                 6  0.550674  0.719957  0.540471      0.739651
# 6            7                 7  0.515293  0.762643  0.529970      0.729847
# 7            8                 8  0.486281  0.777868  0.513009      0.755991
# 8            9                 9  0.459032  0.795541  0.599249      0.710240
# 9           10                10  0.431930  0.816204  0.531967      0.739651

# %%
fig, axes = plt.subplots(1, 2, figsize=(9, 3))

sns.lineplot(data=history_record, x='round_epoch', y='loss', ax=axes[0], label='Training Loss')
sns.lineplot(data=history_record, x='round_epoch', y='val_loss', ax=axes[0], label='Validation Loss')
axes[0].set_xlabel('Training Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

sns.lineplot(data=history_record, x='round_epoch', y='accuracy', ax=axes[1], label='Training Accuracy')
sns.lineplot(data=history_record, x='round_epoch', y='val_accuracy', ax=axes[1], label='Validation Accuracy')
axes[1].set_xlabel('Training Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Augmentation
#
# For the next two questions, we'll generate more data using data augmentations.
#
# Add the following augmentations to your training data generator:
#
# * `rotation_range=50,`
# * `width_shift_range=0.1,`
# * `height_shift_range=0.1,`
# * `zoom_range=0.1,`
# * `horizontal_flip=True,`
# * `fill_mode='nearest'`

# %%
aug_generator = ImageDataGenerator(rescale=1./255,
                                  rotation_range=50,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  zoom_range=0.1,
                                  horizontal_flip=True,
                                  fill_mode='nearest')

train_ds = aug_generator.flow_from_directory(
    './data/train',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',
    shuffle=True
)
# Out:
# Found 3678 images belonging to 2 classes.

# %% [markdown]
# ### Question 5
#
# Let's train our model for 10 more epochs using the same code as previously.
# > **Note:** make sure you don't re-create the model - we want to continue training the model
# we already started training.
#
# What is the mean of test loss for all the epochs for the model trained with augmentations?
#
# * 0.18
# * 0.48  <--
# * 0.78
# * 0.108

# %%
history = model.fit(
    train_ds,
    epochs=10,
    validation_data=test_ds
)
# Out:
# Epoch 1/10
# 184/184 [==============================] - 23s 127ms/step - loss: 0.5127 - accuracy: 0.7591 - val_loss: 0.4814 - val_accuracy: 0.7702
# Epoch 2/10
# 184/184 [==============================] - 23s 125ms/step - loss: 0.5017 - accuracy: 0.7711 - val_loss: 0.4797 - val_accuracy: 0.7571
# Epoch 3/10
# 184/184 [==============================] - 23s 124ms/step - loss: 0.5043 - accuracy: 0.7621 - val_loss: 0.4863 - val_accuracy: 0.7745
# Epoch 4/10
# 184/184 [==============================] - 23s 125ms/step - loss: 0.4876 - accuracy: 0.7757 - val_loss: 0.5119 - val_accuracy: 0.7484
# Epoch 5/10
# 184/184 [==============================] - 23s 125ms/step - loss: 0.4794 - accuracy: 0.7779 - val_loss: 0.4765 - val_accuracy: 0.8017
# Epoch 6/10
# 184/184 [==============================] - 23s 125ms/step - loss: 0.4777 - accuracy: 0.7760 - val_loss: 0.4876 - val_accuracy: 0.7702
# Epoch 7/10
# ...

# %%
print(np.mean(history.history['loss']))
# Out:
# 0.48658354580402374

# %% [markdown]
# ### Question 6
#
# What's the average of test accuracy for the last 5 epochs (from 6 to 10)
# for the model trained with augmentations?
#
# * 0.38
# * 0.58
# * 0.78  <--
# * 0.98

# %%
print(np.mean(history.history['val_accuracy'][-5:]))
# Out:
# 0.7788671016693115

# %%
def update_history_df(history_df, history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    round_epochs = list(range(1, len(history.history['accuracy'])+int(1)))
    
    last_epoch = history_df.iloc[-1]['cumulative_epoch'] if not history_df.empty else 0
    cumulative_epochs = round_epochs.copy() + last_epoch
    
    update_df = pd.DataFrame({'round_epoch': round_epochs,'cumulative_epoch': cumulative_epochs, 
                              'accuracy': acc, 'loss': loss, 'val_accuracy': val_acc, 'val_loss': val_loss}, 
                             columns=['round_epoch', 'cumulative_epoch', 'loss', 'accuracy', 'val_loss', 'val_accuracy'])
    
    history_df = pd.concat([history_df, update_df], ignore_index=True)
    
    return history_df

# %%
history_record = update_history_df(history_record, history)
history_record.tail(10)
# Out:
#     round_epoch  cumulative_epoch      loss  accuracy  val_loss  val_accuracy
# 10            1              11.0  0.512674  0.759108  0.481392      0.770153
# 11            2              12.0  0.501699  0.771071  0.479750      0.757081
# 12            3              13.0  0.504304  0.762099  0.486324      0.774510
# 13            4              14.0  0.487604  0.775693  0.511913      0.748366
# 14            5              15.0  0.479447  0.777868  0.476542      0.801743
# 15            6              16.0  0.477681  0.775965  0.487637      0.770153
# 16            7              17.0  0.479799  0.784666  0.477595      0.774510
# 17            8              18.0  0.475945  0.780043  0.457535      0.796296
# 18            9              19.0  0.475080  0.781947  0.500978      0.762527
# 19           10              20.0  0.471602  0.783034  0.459893      0.790850

# %%
fig, axes = plt.subplots(1, 2, figsize=(9, 3))

sns.lineplot(data=history_record, x='cumulative_epoch', y='loss', ax=axes[0], label='Training Loss')
sns.lineplot(data=history_record, x='cumulative_epoch', y='val_loss', ax=axes[0], label='Validation Loss')
axes[0].set_xlabel('Training Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

sns.lineplot(data=history_record, x='cumulative_epoch', y='accuracy', ax=axes[1], label='Training Accuracy')
sns.lineplot(data=history_record, x='cumulative_epoch', y='val_accuracy', ax=axes[1], label='Validation Accuracy')
axes[1].set_xlabel('Training Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Submit the results
#
# - Submit your results here: https://forms.gle/5sjtM3kzY9TmLmU17
# - If your answer doesn't match options exactly, select the closest one
# - You can submit your solution multiple times. In this case, only the last submission will be used
#
#
# ## Deadline
#
# The deadline for submitting is November 20 (Monday), 23:00 CEST. After that the form will be closed.
